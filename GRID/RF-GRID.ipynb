# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance.csv")
dataset
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes  \
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
#       region_northwest  region_southeast  region_southwest
# 0                False             False              True
# 1                False              True             False
# ...

# %%
dataset=dataset.astype(int)
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes  region_northwest  \
# 0      19   27         0    16884         0           1                 0
# 1      18   33         1     1725         1           0                 0
# 2      28   33         3     4449         1           0                 0
# 3      33   22         0    21984         1           0                 1
# 4      32   28         0     3866         1           0                 1
# ...   ...  ...       ...      ...       ...         ...               ...
# 1333   50   30         3    10600         1           0                 1
# 1334   18   31         0     2205         0           0                 0
# 1335   18   36         0     1629         0           0                 0
# 1336   21   25         0     2007         0           0                 0
# 1337   61   29         0    29141         0           1                 1
#
#       region_southeast  region_southwest
# ...

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes',
#        'region_northwest', 'region_southeast', 'region_southwest'],
#       dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes',
       'region_northwest', 'region_southeast', 'region_southwest']]
indep
# Out:
#       age  bmi  children  sex_male  smoker_yes  region_northwest  \
# 0      19   27         0         0           1                 0
# 1      18   33         1         1           0                 0
# 2      28   33         3         1           0                 0
# 3      33   22         0         1           0                 1
# 4      32   28         0         1           0                 1
# ...   ...  ...       ...       ...         ...               ...
# 1333   50   30         3         1           0                 1
# 1334   18   31         0         0           0                 0
# 1335   18   36         0         0           0                 0
# 1336   21   25         0         0           0                 0
# 1337   61   29         0         0           1                 1
#
#       region_southeast  region_southwest
# 0                    0                 1
# 1                    1                 0
# 2                    1                 0
# ...

# %%
dep=dataset[["charges"]]
dep
# Out:
#       charges
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
# ...       ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(indep, dep, test_size=1/3, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={'criterion':['poisson','absolute_error', 'squared_error', 'friedman_mse'], 'max_features':['auto','sqrt','log2'], 'n_estimators':[10,100]}

# %%
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\HOPE AI\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 11 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\HOPE AI\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\HOPE AI\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\HOPE AI\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
re=grid.cv_results_

# %%
print("TheR_score valueforbestparameter{}:".format(grid.best_params_))
# Out:
# TheR_score valueforbestparameter{'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.003127      0.006254         0.000000        0.000000
# 1        0.000000      0.000000         0.000000        0.000000
# 2        0.081831      0.006321         0.003122        0.006244
# 3        0.519523      0.034901         0.021888        0.007667
# 4        0.062547      0.009880         0.003124        0.006248
# 5        0.581011      0.019944         0.021873        0.007654
# 6        0.000000      0.000000         0.000000        0.000000
# 7        0.003126      0.006251         0.000000        0.000000
# 8        0.118720      0.007669         0.006245        0.007649
# 9        1.133166      0.033699         0.018750        0.011692
# 10       0.140852      0.010022         0.000000        0.000000
# 11       1.340937      0.021372         0.021415        0.007645
# 12       0.000000      0.000000         0.000000        0.000000
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
region_northwest_input=int(input("northeast  0 or 1:"))
region_southeast_input=int(input("southeast  0 or 1:"))
region_southwest_input=int(input("southwest  0 or 1:"))
# Out:
# Age:28
# BMI:22
# Children:0
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:1
# northeast  0 or 1:0
# southeast  0 or 1:0
# southwest  0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input,region_northwest_input,region_southeast_input,region_southwest_input]])

# %%
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[44751.79]

# %%
import pickle
file="finalized_model_svrgrid.sav"

# %%
pickle.dump(re,open(file,'wb'))
